# %%
class CircularArray:
  def __init__(self, lin, st, sz):
    # Initializing Variables
    self.start = st
    self.size = sz
    self.cir = [None]*len(lin)
    k=self.start
    for i in range(len(lin)):
      self.cir[k]=lin[i]
      k=(k+1)%len(self.cir)
    # print(self.cir)

  
  # (TASK 1) Print from index 0 to len(cir) - 1 
  def printFullLinear(self): #Easy
    # To Do
    for i in range(0, len(self.cir)):
      if i!=len(self.cir)-1:
        print(self.cir[i],end=", ")
      else:
        print(self.cir[i])

 # (TASK 2) Print from start index and total size elements
  def printForward(self): #Easy
    # To Do
    k=self.start
    for i in range(self.size):
      if i!=self.size-1:
        print(self.cir[k],end=", ")
      else:
        print(self.cir[k])
      k=(k+1)%len(self.cir) 

     #TASK 3: 
  def printBackward(self): #Easy
    #To Do
    k=(self.start+self.size-1)%len(self.cir)
    for i in range(self.size):
      if i!=self.size-1:
        print(self.cir[k],end=", ")
      else:
        print(self.cir[k])
      k=(k-1)
      if k==-1:
        k=len(self.cir)-1

# TASK 4 With no null cells
  def linearize(self): #Medium
    # To Do
    create_lin=[None]*self.size
    k=self.start
    for i in range(self.size):
      create_lin[i]=self.cir[k]
      k=(k+1)%len(self.cir)
    self.cir=create_lin

# TASK 5: Do not change the Start index
  def resizeStartUnchanged(self, newcapacity): #Medium #
    # To Do
    create_cir=[None]*newcapacity
    k=self.start
    nst=self.start
    for i in range(self.size):
        create_cir[nst]=self.cir[k]
        k=(k+1)%len(self.cir)
        nst=(nst+1)%len(create_cir)
    self.cir=create_cir

# TASK 6: This method will check whether the array is palindrome or not
  def palindromeCheck(self): #Hard
    # To Do
    start= self.start
    end=(self.start+self.size-1)%len(self.cir)

    for i in range(self.size//2):
      if self.cir[start]==self.cir[end]:
        flag=True
      else:
        flag=False
        break
      start=(start+1)%len(self.cir)
      end=(end-1)
      if end==-1:
        end=len(self.cir)-1
    if flag==True:
      print('This array is a palindrome')
    else:
      print("This array is NOT a palindrome")

# This method will sort the values by keeping the start unchanged
  def sort(self):
   #sort
   st=self.start
   for i in range(self.size-1):
     check=(st+1)%len(self.cir)
     for j in range(i+1,self.size):
       print(i,":",self.cir[check])
       if self.cir[st]>self.cir[check]:   #30, None, 10, 20, -30, 20, 50, 
         self.cir[st],self.cir[check]=self.cir[check],self.cir[st]
       check=(check+1)%len(self.cir)
     st=(st+1)%len(self.cir)
   return self.cir
 
  def equivalent(self, cir_arr):
    temp=[None]*len(self.cir)
    st=self.start
    for i in range(self.size):
      temp[st]=self.cir[st]
      s=(st+1)%len(self.cir)
    print("storecir",temp)
    sorted_1= self.sort()
    sorted_2= cir_arr.sort()
    self.linearize()
    cir_arr.linearize()
    print("after sort",self.cir)
    if len(self.cir)!=len(cir_arr.cir):
      flag=False
    else:   
      for i in range(len(self.cir)):
        if self.cir[i]==cir_arr.cir[i]:
          flag=True
        else:
          flag=False
          break
    self.cir=temp
    return flag
 
  # the method take another circular array and returns a linear array containing the common elements between the two circular arrays.
  def intersection(self,c2):
    self.linearize()
    c2.linearize()
    arr_1=self.cir
    arr_2=c2.cir
    count=0
    for i in range(len(arr_1)):
      for j in range(len(arr_2)):
        if arr_1[i]==arr_2[j]:
          count+=1
    new=[None]*count
    idx=0
    for i in range(len(arr_1)):
      for j in range(len(arr_2)):
        if arr_1[i]==arr_2[j]:
          new[idx]=arr_1[i]
          idx+=1
    return new
#.................................................................
lin_arr1 = [10, 20, 30, 40, None]

print("==========Test 1==========")
c1 = CircularArray(lin_arr1, 2, 4)
c1.printFullLinear() # This should print: 40, None, 10, 20, 30
c1.printForward() # This should print: 10, 20, 30, 40
c1.printBackward() # This should print: 40, 30, 20, 10

print("==========Test 2==========")
c1.linearize()
c1.printFullLinear() # This should print: 10, 20, 30, 40

print("==========Test 3==========")
lin_arr2 = [10, 20, 30, 40, 50]
c2 = CircularArray(lin_arr2, 2, 5)
c2.printFullLinear() # This should print: 40, 50, 10, 20, 30
c2.resizeStartUnchanged(8) # parameter --> new Capacity
c2.printFullLinear() # This should print: None, None, 10, 20, 30, 40, 50, None

print("==========Test 4==========")
lin_arr3 = [10, 20, 30, 20, 10, None, None]
c3 = CircularArray(lin_arr3, 3, 5)
c3.printForward() # This should print: 10, 20, 30, 20, 10
c3.palindromeCheck() # This should print: This array is a palindrome

print("==========Test 5==========")
lin_arr4 = [10, 20, 30, 20, None, None, None]
c4 = CircularArray(lin_arr4, 3, 4)
c4.printForward() # This should print: 10, 20, 30, 20
c4.palindromeCheck() # This should print: This array is NOT a palindrome

print("==========Test 6==========")
lin_arr5 = [10, 20, -30, 20, 50, 30, None]
c5 = CircularArray(lin_arr5, 5, 6)
c5.printForward() # This should print: 10, 20, -30, 20, 50, 30
c5.sort()
c5.printForward() # This should print: -30, 10, 20, 20, 30, 50

print("==========Test 7==========")
lin_arr6 = [10, 20, -30, 20, 50, 30, None]
c6 = CircularArray(lin_arr6, 2, 6)
c7 = CircularArray(lin_arr6, 5, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c7.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c7)) # This should print: True

print("==========Test 8==========")
lin_arr7 = [10, 20, -30, 20, 50, 30, None, None, None]
c8 = CircularArray(lin_arr7, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c8.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c8)) # This should print: True

print("==========Test 9==========")
lin_arr8 = [10, 20, 30, 40, 50, 60, None, None, None]
c9 = CircularArray(lin_arr8, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c9.printForward() # This should print: 10, 20, 30, 40, 50, 60
print(c6.equivalent(c9)) # This should print: False

print("==========Test 10==========")
lin_arr9 = [10, 20, 30, 40, 50, None, None, None]
c10 = CircularArray(lin_arr9, 5, 5)
c10.printFullLinear() # This should print: 40, 50, None, None, None, 10, 20, 30
lin_arr10 = [5, 40, 15, 25, 10, 20, 5, None, None, None, None, None]
c11 = CircularArray(lin_arr10, 8, 7)
c11.printFullLinear() # This should print: 10, 20, 5, None, None, None, None, None, 5, 40, 15, 25
output = c10.intersection(c11)
print(output) # This should print: [10, 20, 40]
# Out:
# ==========Test 1==========
# 40, None, 10, 20, 30
# 10, 20, 30, 40
# 40, 30, 20, 10
# ==========Test 2==========
# 10, 20, 30, 40
# ==========Test 3==========
# 40, 50, 10, 20, 30
# None, None, 10, 20, 30, 40, 50, None
# ==========Test 4==========
# 10, 20, 30, 20, 10
# This array is a palindrome
# ==========Test 5==========
# 10, 20, 30, 20
# This array is NOT a palindrome
# ==========Test 6==========
# 10, 20, -30, 20, 50, 30
# 0 : 20
# 0 : -30
# 0 : 20
# 0 : 50
# 0 : 30
# 1 : 10
# 1 : 20
# 1 : 50
# 1 : 30
# 2 : 20
# 2 : 50
# 2 : 30
# 3 : 50
# 3 : 30
# 4 : 30
# -30, 10, 20, 20, 30, 50
# ==========Test 7==========
# 10, 20, -30, 20, 50, 30
# 10, 20, -30, 20, 50, 30
# storecir [None, None, 10, None, None, None, None]
# 0 : 20
# 0 : -30
# 0 : 20
# 0 : 50
# 0 : 30
# 1 : 10
# 1 : 20
# 1 : 50
# 1 : 30
# 2 : 20
# 2 : 50
# 2 : 30
# 3 : 50
# 3 : 30
# 4 : 30
# 0 : 20
# 0 : -30
# 0 : 20
# 0 : 50
# 0 : 30
# 1 : 10
# 1 : 20
# 1 : 50
# 1 : 30
# 2 : 20
# 2 : 50
# 2 : 30
# 3 : 50
# 3 : 30
# 4 : 30
# after sort [-30, 10, 20, 20, 30, 50]
# True
# ==========Test 8==========
# 10, None, None, None, None, None
# 10, 20, -30, 20, 50, 30
# storecir [None, None, 10, None, None, None, None]
# 0 : None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cd8a5a478d40> in <module>()
#     197 c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
#     198 c8.printForward() # This should print: 10, 20, -30, 20, 50, 30
# --> 199 print(c6.equivalent(c8)) # This should print: True
#     200
#     201 print("==========Test 9==========")
#
# <ipython-input-20-cd8a5a478d40> in equivalent(self, cir_arr)
#     109       s=(st+1)%len(self.cir)
#     110     print("storecir",temp)
# --> 111     sorted_1= self.sort()
#     112     sorted_2= cir_arr.sort()
#     113     self.linearize()
#
# <ipython-input-20-cd8a5a478d40> in sort(self)
#      96      for j in range(i+1,self.size):
#      97        print(i,":",self.cir[check])
# ---> 98        if self.cir[st]>self.cir[check]:   #30, None, 10, 20, -30, 20, 50,
#      99          self.cir[st],self.cir[check]=self.cir[check],self.cir[st]
#     100        check=(check+1)%len(self.cir)
#
# TypeError: '>' not supported between instances of 'int' and 'NoneType'

# %%
class CircularArray:
  def __init__(self, lin, st, sz):
    # Initializing Variables
    self.start = st
    self.size = sz
    self.cir = [None]*len(lin)
    k=self.start
    for i in range(len(lin)):
      self.cir[k]=lin[i]
      k=(k+1)%len(self.cir)
    # print(self.cir)

  
  # (TASK 1) Print from index 0 to len(cir) - 1 
  def printFullLinear(self): #Easy
    # To Do
    for i in range(0, len(self.cir)):
      if i!=len(self.cir)-1:
        print(self.cir[i],end=", ")
      else:
        print(self.cir[i])

 # (TASK 2) Print from start index and total size elements
  def printForward(self): #Easy
    # To Do
    k=self.start
    for i in range(self.size):
      if i!=self.size-1:
        print(self.cir[k],end=", ")
      else:
        print(self.cir[k])
      k=(k+1)%len(self.cir) 

     #TASK 3: 
  def printBackward(self): #Easy
    #To Do
    k=(self.start+self.size-1)%len(self.cir)
    for i in range(self.size):
      if i!=self.size-1:
        print(self.cir[k],end=", ")
      else:
        print(self.cir[k])
      k=(k-1)
      if k==-1:
        k=len(self.cir)-1

# TASK 4 With no null cells
  def linearize(self): #Medium
    # To Do
    create_lin=[None]*self.size
    k=self.start
    for i in range(self.size):
      create_lin[i]=self.cir[k]
      k=(k+1)%len(self.cir)
    self.cir=create_lin

# TASK 5: Do not change the Start index
  def resizeStartUnchanged(self, newcapacity): #Medium #
    # To Do
    create_cir=[None]*newcapacity
    k=self.start
    nst=self.start
    for i in range(self.size):
        create_cir[nst]=self.cir[k]
        k=(k+1)%len(self.cir)
        nst=(nst+1)%len(create_cir)
    self.cir=create_cir

# TASK 6: This method will check whether the array is palindrome or not
  def palindromeCheck(self): #Hard
    # To Do
    start= self.start
    end=(self.start+self.size-1)%len(self.cir)

    for i in range(self.size//2):
      if self.cir[start]==self.cir[end]:
        flag=True
      else:
        flag=False
        break
      start=(start+1)%len(self.cir)
      end=(end-1)
      if end==-1:
        end=len(self.cir)-1
    if flag==True:
      print('This array is a palindrome')
    else:
      print("This array is NOT a palindrome")

# This method will sort the values by keeping the start unchanged
  def sort(self):
   #sort
   st=self.start
   for i in range(self.size-1):
     check=(st+1)%len(self.cir)
     for j in range(i+1,self.size):
       if self.cir[st]>self.cir[check]:
         self.cir[st],self.cir[check]=self.cir[check],self.cir[st]
       check=(check+1)%len(self.cir)
     st=(st+1)%len(self.cir)
   return self.cir

# This method will check the given array across the base array and if they are equivalent interms of values return true, or else return false
  # def equivalent(self, cir_arr):
  #   temp=self.cir 
  #   print("temp",temp)
  #   sorted_1= self.sort()
  #   sorted_2= cir_arr.sort()
  #   print("after sort",self.cir)
  #   st_1=self.start
  #   st_2=cir_arr.start
  #   if self.size!=cir_arr.size:
  #     flag=False
  #   else:
  #     sz=self.size
  #     for i in range(sz):
  #       if sorted_1[st_1]==sorted_2[st_2]:
  #         flag=True
  #         st_1=(st_1+1)%len(sorted_1)
  #         st_2=(st_2+1)%len(sorted_2)
  #       else:
  #         flag=False
  #         break
  #   print("after near end",self.cir)
  #   self.cir=temp
  #   return flag
  # def equivalent(self, cir_arr):
  #   temp=self.cir 
  #   print("temp",temp)
  #   sorted_1= self.sort()
  #   sorted_2= cir_arr.sort()
  #   print("after sort",self.cir)
  #   st_1=self.start
  #   st_2=cir_arr.start
  #   self.linearize()
  #   cir_arr.linearize()
  #   if self.size!=cir_arr.size:
  #     flag=False
  #   else:
  #     sz=self.size
  #     for i in range(sz):
  #       if sorted_1[st_1]==sorted_2[st_2]:
  #         flag=True
  #         # st_1=(st_1+1)%len(sorted_1)
  #         # st_2=(st_2+1)%len(sorted_2)
  #       else:
  #         flag=False
  #         break
  #   print("after near end",self.cir)
  #   self.cir=temp
  #   return flag  
  def equivalent(self, cir_arr):
    temp=[None]*len(self.cir)
    s=self.start
    for i in range(self.size):
      temp[s]=self.cir[s]
      s=(s+1)%len(self.cir)
    sorted_1= self.sort()
    sorted_2= cir_arr.sort()
    self.linearize()
    cir_arr.linearize()
    if len(self.cir)!=len(cir_arr.cir):
      flag=False
    else:   
      for i in range(len(self.cir)):
        if self.cir[i]==cir_arr.cir[i]:
          flag=True
        else:
          flag=False
          break
    self.cir=temp
    return flag



  
  # the method take another circular array and returns a linear array containing the common elements between the two circular arrays.
  def intersection(self,c2):
    self.linearize()
    c2.linearize()
    arr_1=self.cir
    arr_2=c2.cir
    count=0
    for i in range(len(arr_1)):
      for j in range(len(arr_2)):
        if arr_1[i]==arr_2[j]:
          count+=1
    new=[None]*count
    idx=0
    for i in range(len(arr_1)):
      for j in range(len(arr_2)):
        if arr_1[i]==arr_2[j]:
          new[idx]=arr_1[i]
          idx+=1
    return new
#.................................................................
lin_arr1 = [10, 20, 30, 40, None]

print("==========Test 1==========")
c1 = CircularArray(lin_arr1, 2, 4)
c1.printFullLinear() # This should print: 40, None, 10, 20, 30
c1.printForward() # This should print: 10, 20, 30, 40
c1.printBackward() # This should print: 40, 30, 20, 10

print("==========Test 2==========")
c1.linearize()
c1.printFullLinear() # This should print: 10, 20, 30, 40

print("==========Test 3==========")
lin_arr2 = [10, 20, 30, 40, 50]
c2 = CircularArray(lin_arr2, 2, 5)
c2.printFullLinear() # This should print: 40, 50, 10, 20, 30
c2.resizeStartUnchanged(8) # parameter --> new Capacity
c2.printFullLinear() # This should print: None, None, 10, 20, 30, 40, 50, None

print("==========Test 4==========")
lin_arr3 = [10, 20, 30, 20, 10, None, None]
c3 = CircularArray(lin_arr3, 3, 5)
c3.printForward() # This should print: 10, 20, 30, 20, 10
c3.palindromeCheck() # This should print: This array is a palindrome

print("==========Test 5==========")
lin_arr4 = [10, 20, 30, 20, None, None, None]
c4 = CircularArray(lin_arr4, 3, 4)
c4.printForward() # This should print: 10, 20, 30, 20
c4.palindromeCheck() # This should print: This array is NOT a palindrome

print("==========Test 6==========")
lin_arr5 = [10, 20, -30, 20, 50, 30, None]
c5 = CircularArray(lin_arr5, 5, 6)
c5.printForward() # This should print: 10, 20, -30, 20, 50, 30
c5.sort()
c5.printForward() # This should print: -30, 10, 20, 20, 30, 50

print("==========Test 7==========")
lin_arr6 = [10, 20, -30, 20, 50, 30, None]
c6 = CircularArray(lin_arr6, 2, 6)
c7 = CircularArray(lin_arr6, 5, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c7.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c7)) # This should print: True

print("==========Test 8==========")
lin_arr7 = [10, 20, -30, 20, 50, 30, None, None, None]
c8 = CircularArray(lin_arr7, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c8.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c8)) # This should print: True

print("==========Test 9==========")
lin_arr8 = [10, 20, 30, 40, 50, 60, None, None, None]
c9 = CircularArray(lin_arr8, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c9.printForward() # This should print: 10, 20, 30, 40, 50, 60
print(c6.equivalent(c9)) # This should print: False

print("==========Test 10==========")
lin_arr9 = [10, 20, 30, 40, 50, None, None, None]
c10 = CircularArray(lin_arr9, 5, 5)
c10.printFullLinear() # This should print: 40, 50, None, None, None, 10, 20, 30
lin_arr10 = [5, 40, 15, 25, 10, 20, 5, None, None, None, None, None]
c11 = CircularArray(lin_arr10, 8, 7)
c11.printFullLinear() # This should print: 10, 20, 5, None, None, None, None, None, 5, 40, 15, 25
output = c10.intersection(c11)
print(output) # This should print: [10, 20, 40]
# Out:
# ==========Test 1==========
# 40, None, 10, 20, 30
# 10, 20, 30, 40
# 40, 30, 20, 10
# ==========Test 2==========
# 10, 20, 30, 40
# ==========Test 3==========
# 40, 50, 10, 20, 30
# None, None, 10, 20, 30, 40, 50, None
# ==========Test 4==========
# 10, 20, 30, 20, 10
# This array is a palindrome
# ==========Test 5==========
# 10, 20, 30, 20
# This array is NOT a palindrome
# ==========Test 6==========
# 10, 20, -30, 20, 50, 30
# -30, 10, 20, 20, 30, 50
# ==========Test 7==========
# 10, 20, -30, 20, 50, 30
# 10, 20, -30, 20, 50, 30
# storecir [30, None, 10, 20, -30, 20, 50]
# after sort [-30, 10, 20, 20, 30, 50]
# True
# ==========Test 8==========
# 10, 20, -30, 20, 50, 30
# 10, 20, -30, 20, 50, 30
# storecir [30, None, 10, 20, -30, 20, 50]
# after sort [-30, 10, 20, 20, 30, 50]
# True
# ==========Test 9==========
# 10, 20, -30, 20, 50, 30
# 10, 20, 30, 40, 50, 60
# storecir [30, None, 10, 20, -30, 20, 50]
# after sort [-30, 10, 20, 20, 30, 50]
# False
# ==========Test 10==========
# 40, 50, None, None, None, 10, 20, 30
# 10, 20, 5, None, None, None, None, None, 5, 40, 15, 25
# [10, 20, 40]

# %%
class CircularArray:
  def __init__(self, lin, st, sz):
    # Initializing Variables
    self.start = st
    self.size = sz
    self.cir = [None]*len(lin)
    k=self.start
    for i in range(len(lin)):
      self.cir[k]=lin[i]
      k=(k+1)%len(self.cir)    
    # print("cir",self.cir)

  def equivalent(self, cir_arr):
    temp=[None]*len(self.cir)
    s=self.start
    for i in range(self.size):
      temp[s]=self.cir[s]
      s=(s+1)%len(self.cir)
    print("storecir",temp)
    sorted_1= self.sort()
    sorted_2= cir_arr.sort()
    self.linearize()
    cir_arr.linearize()
    print("after sort",self.cir)
    if self.size!=cir_arr.size:
        flag=False
    else:
       for i in range(self.size):
        if sorted_1[i]==sorted_2[i]:
          flag=True
        else:
           flag=False
           break
    print("after near end",self.cir)
    self.cir=temp
print("==========Test 7==========")
lin_arr6 = [10, 20, -30, 20, 50, 30, None]
c6 = CircularArray(lin_arr6, 2, 6)
c7 = CircularArray(lin_arr6, 5, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c7.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c7)) # This should print: True

print("==========Test 8==========")
lin_arr7 = [10, 20, -30, 20, 50, 30, None, None, None]
c8 = CircularArray(lin_arr7, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c8.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c8)) # This should print: True

print("==========Test 9==========")
lin_arr8 = [10, 20, 30, 40, 50, 60, None, None, None]
c9 = CircularArray(lin_arr8, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c9.printForward() # This should print: 10, 20, 30, 40, 50, 60
print(c6.equivalent(c9)) # This should print: False
# Out:
# ==========Test 7==========
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-eda3cc26ca5e> in <module>()
#      38 c6 = CircularArray(lin_arr6, 2, 6)
#      39 c7 = CircularArray(lin_arr6, 5, 6)
# ---> 40 c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
#      41 c7.printForward() # This should print: 10, 20, -30, 20, 50, 30
#      42 print(c6.equivalent(c7)) # This should print: True
#
# AttributeError: 'CircularArray' object has no attribute 'printForward'

# %%
class CircularArray:
  def __init__(self, lin, st, sz):
    # Initializing Variables
    self.start = st
    self.size = sz
    self.cir = [None]*len(lin)
    k=self.start
    for i in range(len(lin)):
      self.cir[k]=lin[i]
      k=(k+1)%len(self.cir)    
    # print("cir",self.cir)
# TASK 4 With no null cells
  def linearize(self): #Medium
    # To Do
    print("TASK 4: linearize")
    create_lin=[None]*self.size
    k=self.start
    for i in range(self.size):
      create_lin[i]=self.cir[k]
      k=(k+1)%len(self.cir)
    self.cir=create_lin

  def intersection(self,c2):
    arr_1=self.linearize()
    arr_2=c2.linearize()
    print(arr_1)



print("==========Test 10==========")
lin_arr9 = [10, 20, 30, 40, 50, None, None, None]
c10 = CircularArray(lin_arr9, 5, 5)
# This should print: 40, 50, None, None, None, 10, 20, 30
lin_arr10 = [5, 40, 15, 25, 10, 20, 5, None, None, None, None, None]
c11 = CircularArray(lin_arr10, 8, 7)
# This should print: 10, 20, 5, None, None, None, None, None, 5, 40, 15, 25
output = c10.intersection(c11)
print(output) # This should print: [10, 20, 40]
# Out:
# ==========Test 10==========
# TASK 4: linearize
# TASK 4: linearize
# None
# None

# %%
class CircularArray:
  def __init__(self, lin, st, sz):
    # Initializing Variables
    self.start = st
    self.size = sz
    self.cir = [None]*len(lin)
    k=self.start
    for i in range(len(lin)):
      self.cir[k]=lin[i]
      k=(k+1)%len(self.cir)    
    print("cir",self.cir)

lin_arr5 = [10, 20, -30, 20, 50, 30, None]
c5 = CircularArray(lin_arr5, 5, 6)
# Out:
# cir [-30, 20, 50, 30, None, 10, 20]

# %%
lin_arr5 = [10, 20, -30, 20, 50, 30, None]
c5 = CircularArray(lin_arr5, 5, 6)
print(c5.cir)
# Out:
# [-30, 20, 50, 30, None, 10, 20]

# %%
a=[-30, 20, 50, 30, None, 10, 20]  # 20, 20, 30, 50, N, -30, 10 
st=5
sz=6
for i in range(sz-1):
  p=(st+1)%len(a)
  for j in range(i+1,sz):
    if a[st]>a[p]:
      a[st],a[p]=a[p],a[st]
    p=(p+1)%len(a)
  st=(st+1)%len(a)
print(a)
# Out:
# [20, 20, 30, 50, None, -30, 10]

# %%
a=[-30, 20, 50, 30, None, 10, 20]  # 20, 20, 30, 50, N, -30, 10 
st=5
p=st+1
sz=6
last=(st+sz-1)%len(a)


for i in range(st,last-1):
  for j in range(i+1,last):
    if a[i]>a[j]:
      a[i],a[j]=a[j],a[i]
    
print(a)
# Out:
# [-30, 20, 50, 30, None, 10, 20]

# %%
class CircularArray:
  def __init__(self, lin, st, sz):
    # Initializing Variables
    self.start = st
    self.size = sz
    self.cir = [None]*len(lin)
    k=self.start
    for i in range(len(lin)):
      self.cir[k]=lin[i]
      k=(k+1)%len(self.cir)
    print(self.cir)


 # (TASK 2) Print from start index and total size elements
  def printForward(self): #Easy
    # To Do
    print("TASK 2: printForward")
    k=self.start
    for i in range(self.size):
      if i!=self.size-1:
        print(self.cir[k],end=", ")
      else:
        print(self.cir[k])
      k=(k+1)%len(self.cir) 

  def sort(self):
   #sort
   st=self.start
   for i in range(self.size-1):
     check=(st+1)%len(self.cir)
     for j in range(i+1,self.size):
       if self.cir[st]>self.cir[check]:
         self.cir[st],self.cir[check]=self.cir[check],self.cir[st]
       check=(check+1)%len(self.cir)
     st=(st+1)%len(self.cir)

# This method will check the given array across the base array and if they are equivalent interms of values return true, or else return false
  def equivalent(self, cir_arr):
    # To Do    
    sorted_1= self.sort()
    sorted_2= cir_arr.sort()
    

    





print("==========Test 7==========")
lin_arr6 = [10, 20, -30, 20, 50, 30, None]
c6 = CircularArray(lin_arr6, 2, 6)
c7 = CircularArray(lin_arr6, 5, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c7.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c7)) # This should print: True

print("==========Test 8==========")
lin_arr7 = [10, 20, -30, 20, 50, 30, None, None, None]
c8 = CircularArray(lin_arr7, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c8.printForward() # This should print: 10, 20, -30, 20, 50, 30
print(c6.equivalent(c8)) # This should print: True

print("==========Test 9==========")
lin_arr8 = [10, 20, 30, 40, 50, 60, None, None, None]
c9 = CircularArray(lin_arr8, 8, 6)
c6.printForward() # This should print: 10, 20, -30, 20, 50, 30
c9.printForward() # This should print: 10, 20, 30, 40, 50, 60
print(c6.equivalent(c9)) # This should print: False

# %%
class CircularArray:
  def __init__(self, lin, st, sz):
    # Initializing Variables
    self.start = st
    self.size = sz
    self.cir = [None]*len(lin)
    k=self.start
    for i in range(len(lin)):
      self.cir[k]=lin[i]
      k=(k+1)%len(self.cir)
    print(self.cir)


  def sort(self):
   #sort
   st=self.start
   for i in range(self.size-1):
     check=(st+1)%len(self.cir)
     for j in range(i+1,self.size):
       if self.cir[st]>self.cir[check]:
         self.cir[st],self.cir[check]=self.cir[check],self.cir[st]
       check=(check+1)%len(self.cir)
     st=(st+1)%len(self.cir)
   return self.cir

# This method will check the given array across the base array and if they are equivalent interms of values return true, or else return false
  def equivalent(self, cir_arr):
    # To Do    
    sorted_1= self.sort()
    sorted_2= cir_arr.sort()
    st_1=self.start
    st_2=cir_arr.start

    if self.size!=cir_arr.size:
      flag=False
    else:
      sz=self.size
      for i in range(sz):
        if sorted_1[st_1]==sorted_2[st_2]:
          flag=True
          st_1=(st_1+1)%len(sorted_1)
          st_2=(st_2+1)%len(sorted_2)
        else:
          flag=False
          break
    return flag



    

    





print("==========Test 7==========")
lin_arr6 = [10, 20, -30, 20, 50, 30, None]
c6 = CircularArray(lin_arr6, 2, 6)
c7 = CircularArray(lin_arr6, 5, 6)

print(c6.equivalent(c7)) # This should print: True

print("==========Test 8==========")
lin_arr7 = [10, 20, -30, 20, 50, 30, None, None, None]
c8 = CircularArray(lin_arr7, 8, 6)
print(c6.equivalent(c8)) # This should print: True

print("==========Test 9==========")
lin_arr8 = [10, 20, 30, 40, 50, 60, None, None, None]
c9 = CircularArray(lin_arr8, 8, 6)
print(c6.equivalent(c9)) # This should print: False
# Out:
# ==========Test 7==========
# True
# ==========Test 8==========
# True
# ==========Test 9==========
# False
