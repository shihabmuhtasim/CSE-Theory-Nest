# %%
count =0
while(count<10):
  print("hello")
  count=count+1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
i=o

# %%
print("hagu")
# Out:
# hagu

# %%
# a) 24, 18, 12, 6, 0, -6

# initialize loop counter
counter = 24

# loop structure
while counter >= -6:
    
    #inside loop body
    if counter == -6:
        print(counter, end = "") 
    else:
        print(counter, end = ", ") 
     
    counter = counter - 6 #updating loop counter
    #inside loop body
    
#outside loop body
# Out:
# 24, 18, 12, 6, 0, -6

# %%
# b)-10, -5, 0, 5, 10, 15, 20
counter = -10
while counter <=20:
  if (counter==20):
    print(counter, end = "")
  else:
    print(counter, end = ",") 
  counter = counter + 5
# Out:
# -10,-5,0,5,10,15,20

# %%
start=25
end=30
check=4
while start<=end:
    count=0
    while start>=0:
        start=start//10
        count+=1
    print(count)
    start+=1
